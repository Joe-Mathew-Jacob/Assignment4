# %% [markdown]
# #Assignment number 4

# %% [markdown]
# #upload data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #upload data set

# %%
df=pd.read_csv("D:/DSA/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #passenger id as index column

# %%
df1=df.set_index("PassengerId")

# %%
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
#  #Check the basic details of the dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#Fill in all the missing values present in all the columns in the dataset

# %%
for i in ["Age"]:
    df1[i] = df1[i].fillna(df1[i].median())

# %%
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#Handling missing values of categorical variable using mode

# %%
df3=df1

# %%
ind=df3["Cabin"].mode()

# %%
ind
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# dtype: object

# %%
ind[0]
# Out:
# 'B96 B98'

# %%
for i in ["Cabin"]:
    df3[i]=df3[i].fillna(ind[1])

# %%
df3
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df3.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    2
# dtype: int64

# %%
ind1=df3["Embarked"].mode()
for i in ["Embarked"]:
    df3[i]=df3[i].fillna(ind1[0])

# %%
df3
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df3.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
#Check and handle outliers in at least 3 columns in the dataset

# %%
df3.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df3.boxplot('SibSp')
# Out:
# <AxesSubplot:>

# %%
q1=np.percentile(df3["SibSp"],25)

# %%
q1
# Out:
# 0.0

# %%
q3=np.percentile(df3["SibSp"],75)

# %%
q3
# Out:
# 1.0

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 1.0

# %%
low_lmt=q1-1.5*iqr
upper_lmt=q3+1.5*iqr
low_lmt
# Out:
# -1.5

# %%
upper_lmt
# Out:
# 2.5

# %%
df3["SibSp"].describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
outlier=[]
for x in df3["SibSp"]:
    if x < low_lmt or x> upper_lmt:
        outlier.append(x)

# %%
ind4=df3["SibSp"] > upper_lmt

df3.loc[ind4].index
# Out:
# Int64Index([  8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
#             165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
#             375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
#             793, 814, 820, 825, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
df3=df3.drop([  8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
            470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 867 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  867 non-null    int64
#  1   Pclass    867 non-null    int64
#  2   Name      867 non-null    object
#  3   Sex       867 non-null    object
#  4   Age       867 non-null    float64
#  5   SibSp     867 non-null    int64
#  6   Parch     867 non-null    int64
#  7   Ticket    867 non-null    object
#  8   Fare      867 non-null    float64
#  9   Cabin     867 non-null    object
#  10  Embarked  867 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 81.3+ KB

# %%
df3.boxplot("Fare")
# Out:
# <AxesSubplot:>

# %%
    Q1 = np.percentile(df3["Fare"],25)

# %%
Q1
# Out:
# 7.8958

# %%
df3["Fare"].describe()
# Out:
# count    867.000000
# mean      32.119621
# std       50.006446
# min        0.000000
# 25%        7.895800
# 50%       14.108300
# 75%       30.847900
# max      512.329200
# Name: Fare, dtype: float64

# %%
    Q3 = np.percentile(df3["Fare"],75)

# %%
Q3
# Out:
# 30.8479

# %%
IQR=Q3-Q1
IQR
# Out:
# 22.952099999999998

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit
# Out:
# -26.532349999999994

# %%
upper_limit
# Out:
# 65.27605

# %%
outlier1=[]
for j in df3["Fare"]:
    if j < lower_limit or j > upper_limit:
        outlier1.append(j)

# %%
ind5= df3["Fare"] > upper_limit
df3.loc[ind5].index
# Out:
# Int64Index([  2,  28,  32,  35,  53,  62,  63,  73,  89, 103,
#             ...
#             793, 803, 821, 830, 836, 847, 850, 857, 864, 880],
#            dtype='int64', name='PassengerId', length=114)

# %%
df3=df3.drop([  2,  28,  32,  35,  53,  62,  63,  73,  89, 103,793, 803, 821, 830, 836, 847, 850, 857, 864, 880])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  847 non-null    int64
#  1   Pclass    847 non-null    int64
#  2   Name      847 non-null    object
#  3   Sex       847 non-null    object
#  4   Age       847 non-null    float64
#  5   SibSp     847 non-null    int64
#  6   Parch     847 non-null    int64
#  7   Ticket    847 non-null    object
#  8   Fare      847 non-null    float64
#  9   Cabin     847 non-null    object
#  10  Embarked  847 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
#Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
df3
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
df4=df3

# %%
df4
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
a=df4[['Pclass','Age', 'SibSp', 'Parch','Fare']]

# %%
a
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500
# 6                 3  28.0      0      0   8.4583
# ...             ...   ...    ...    ...      ...
# 887               2  27.0      0      0  13.0000
# 888               1  19.0      0      0  30.0000
# 889               3  28.0      1      2  23.4500
# 890               1  26.0      0      0  30.0000
# 891               3  32.0      0      0   7.7500
#
# [847 rows x 5 columns]

# %%
b=df4[['Survived',  'Name', 'Sex','Ticket', 'Cabin', 'Embarked']]

# %%
from sklearn.preprocessing import MinMaxScaler
minmax_scaler = MinMaxScaler(feature_range = (0,1))
a = minmax_scaler.fit_transform(a)

# %%
a=pd.DataFrame(a)

# %%
a.columns=[['Pclass','Age', 'SibSp', 'Parch','Fare']]

# %%
a
# Out:
#     Pclass       Age  SibSp     Parch      Fare
# 0      1.0  0.246753  0.125  0.000000  0.014151
# 1      1.0  0.298701  0.000  0.000000  0.015469
# 2      0.0  0.415584  0.125  0.000000  0.103644
# 3      1.0  0.415584  0.000  0.000000  0.015713
# 4      1.0  0.324675  0.000  0.000000  0.016510
# ..     ...       ...    ...       ...       ...
# 842    0.5  0.311688  0.000  0.000000  0.025374
# 843    0.0  0.207792  0.000  0.000000  0.058556
# 844    1.0  0.324675  0.125  0.333333  0.045771
# 845    0.0  0.298701  0.000  0.000000  0.058556
# 846    1.0  0.376623  0.000  0.000000  0.015127
#
# [847 rows x 5 columns]

# %%
a.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  847.000000  847.000000  847.000000  847.000000  847.000000
# mean     0.662338    0.351140    0.056818    0.057064    0.059244
# std      0.414610    0.159487    0.121858    0.131756    0.094533
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.259740    0.000000    0.000000    0.015412
# 50%      1.000000    0.324675    0.000000    0.000000    0.025374
# 75%      1.000000    0.415584    0.125000    0.000000    0.058263
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
c=pd.concat([a,b],axis=1,join='inner')

# %%
c
# Out:
#      (Pclass,)    (Age,)  (SibSp,)  (Parch,)   (Fare,)  Survived  \
# 1          1.0  0.298701     0.000  0.000000  0.015469         0
# 3          1.0  0.415584     0.000  0.000000  0.015713         1
# 4          1.0  0.324675     0.000  0.000000  0.016510         1
# 5          0.0  0.662338     0.000  0.000000  0.101229         0
# 6          1.0  0.311688     0.000  0.333333  0.021731         0
# ..         ...       ...       ...       ...       ...       ...
# 842        0.5  0.311688     0.000  0.000000  0.025374         0
# 843        0.0  0.207792     0.000  0.000000  0.058556         1
# 844        1.0  0.324675     0.125  0.333333  0.045771         0
# 845        0.0  0.298701     0.000  0.000000  0.058556         0
# 846        1.0  0.376623     0.000  0.000000  0.015127         0
#
#                                              Name     Sex            Ticket  \
# 1                         Braund, Mr. Owen Harris    male         A/5 21171
# ...
